# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(12,7)})

# %%
# Загружаем таблицу и смотрим на её содержимое
df = pd.read_csv('data.csv')
df = df.replace({'diagnosis':{'M':1, 'B':0}})
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# 1       1326.0          0.08474           0.07864         0.08690
# 2       1203.0          0.10960           0.15990         0.19740
# 3        386.1          0.14250           0.28390         0.24140
# 4       1297.0          0.10030           0.13280         0.19800
# ..         ...              ...               ...             ...
# 564     1479.0          0.11100           0.11590         0.24390
# 565     1261.0          0.09780           0.10340         0.14400
# 566      858.1          0.08455           0.10230         0.09251
# 567     1265.0          0.11780           0.27700         0.35140
# 568      181.0          0.05263           0.04362         0.00000
#
#      concave points_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                0.14710  ...          17.33           184.60      2019.0
# 1                0.07017  ...          23.41           158.80      1956.0
# 2                0.12790  ...          25.53           152.50      1709.0
# 3                0.10520  ...          26.50            98.87       567.7
# 4                0.10430  ...          16.67           152.20      1575.0
# ..                   ...  ...            ...              ...         ...
# 564              0.13890  ...          26.40           166.10      2027.0
# 565              0.09791  ...          38.25           155.00      1731.0
# 566              0.05302  ...          34.12           126.70      1124.0
# 567              0.15200  ...          39.42           184.60      1821.0
# 568              0.00000  ...          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst  \
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
#      Unnamed: 32
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 564          NaN
# 565          NaN
# 566          NaN
# 567          NaN
# 568          NaN
#
# [569 rows x 33 columns]

# %%
# Строим тепловую карту корреляции параметров, чтобы в дальнейшем понимать какие графики нам дадут полезную информацию, а какие нет
sns.heatmap(df[df.columns[1:12]].corr(), annot=True);

# %%
# Примеры полезных графиков
sns.scatterplot(df, x="radius_mean", y="perimeter_mean")
# sns.scatterplot(df, x="radius_mean", y="area_mean")
# Out:
# <AxesSubplot: xlabel='radius_mean', ylabel='perimeter_mean'>

# %%
# Примеры бесполезных графиков
sns.scatterplot(df, x="radius_mean", y="fractal_dimension_mean")
# sns.scatterplot(df, x="texture_mean", y="smoothness_mean")
# Out:
# <AxesSubplot: xlabel='radius_mean', ylabel='fractal_dimension_mean'>

# %%
sns.boxplot(df, x='diagnosis', y='radius_mean', palette="Set2").set(xticklabels=["Злокачественный", "Доброкачественный"], xlabel='Диагноз', ylabel='Средний радиус');
# Out:
# C:\Users\ars4z\AppData\Local\Temp\ipykernel_6828\196767968.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(df, x='diagnosis', y='radius_mean', palette="Set2").set(xticklabels=["Злокачественный", "Доброкачественный"], xlabel='Диагноз', ylabel='Средний радиус');
# C:\Users\ars4z\AppData\Local\Temp\ipykernel_6828\196767968.py:1: UserWarning: FixedFormatter should only be used together with FixedLocator
#   sns.boxplot(df, x='diagnosis', y='radius_mean', palette="Set2").set(xticklabels=["Злокачественный", "Доброкачественный"], xlabel='Диагноз', ylabel='Средний радиус');
